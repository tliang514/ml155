# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import nltk
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures

with open('training_data.txt','r') as train_f:
    train_iter = csv.reader(train_f, delimiter='|')
    trainlist = [i for i in train_iter]
train_raw = np.asarray(trainlist)

# %%
#nltk bigram method
def bigram_words(words, score_fn=BigramAssocMeasures.chi_sq, n=1000):
    bigram_finder = BigramCollocationFinder.from_words(words)
    bigrams = bigram_finder.nbest(score_fn, n)
    return bigrams

train_bag = bigram_words(train_raw[0])
print train_bag
# Out:
# [("''", 'republican'), ("'s", 'gentleman'), ('--', 'system'), ('000', 'allow'), ('1/2', 'particularli'), ('10', 'florida'), ('100', '30'), ('11', 'heat'), ('12', 'earli'), ('15', '200'), ('20', 'bankruptci'), ('200', 'longer'), ('2001', 'tonight'), ('2003', 'intent'), ('2004', 'break'), ('2005', 'hope'), ('2006', 'suggest'), ('25', 'agricultur'), ('30', 'demand'), ('40', 'armi'), ('418', 'subject'), ('50', 'rather'), ('500', 'origin'), ('60', 'short'), ('9/11', 'consider'), ('``', 'billion'), ('abil', 'far'), ('abl', 'substitut'), ('absolut', 'vital'), ('abus', 'motion'), ('accept', 'decad'), ('access', 'exampl'), ('accord', 'reject'), ('account', 'person'), ('achiev', 'add'), ('across', 'abil'), ('act', 'import'), ('action', 'monei'), ('activ', 'intern'), ('actual', 'women'), ('ad', 'expect'), ('add', 'basic'), ('addit', 'servic'), ('address', 'chang'), ('adequ', 'charg'), ('administr', 'give'), ('adopt', 'themselv'), ('advanc', 'evid'), ('affect', 'seen'), ('afford', 'ago'), ('afghanistan', 'yesterdai'), ('agenc', 'schiavo'), ('ago', 'access'), ('agre', 'dure'), ('agreement', 'live'), ('agricultur', 'equal'), ('ahp', 'impact'), ('aid', 'everybodi'), ('air', 'start'), ('airlin', 'thought'), ('aisl', 'awai'), ('allow', 'major'), ('almost', 'violat'), ('alon', 'mrs.'), ('along', 'send'), ('alreadi', 'gang'), ('also', 'doe'), ('altern', 'driver'), ('although', 'anyon'), ('alwai', 'penalti'), ('america', 'back'), ('american', 'support'), ('among', 'alwai'), ('amount', 'manufactur'), ('amp', 'singl'), ('amt', 'contract'), ('ani', 'h.r.'), ('anoth', 'done'), ('answer', '15'), ('anyon', 'award'), ('anyth', 'express'), ('appeal', 'third'), ('appli', 'full'), ('applic', 'alon'), ('appoint', 'earn'), ('appreci', 'larg'), ('approach', 'contain'), ('appropri', 'children'), ('approv', 'practic'), ('ar', 'bill'), ('area', 'concern'), ('argu', 'statu'), ('argument', 'weaken'), ('arm', 'delai'), ('armi', 'introduc'), ('around', 'parti'), ('ask', 'look'), ('assist', 'foreign'), ('associ', 'serv'), ('asylum', 'univers'), ('attack', 'success'), ('attempt', '25'), ('attent', 'refer'), ('attornei', 'coverag'), ('author', 'econom'), ('avail', 'proud'), ('averag', 'bad'), ('avoid', 'irrespons'), ('awai', 'medic'), ('award', 'weapon'), ('back', 'good'), ('bad', 'lawyer'), ('bahrain', 'due'), ('balanc', 'pass'), ('bankruptci', 'still'), ('base', 'reason'), ('basi', 'michigan'), ('basic', 'ad'), ('becaus', 'million'), ('becom', 'fuel'), ('befor', 'well'), ('begin', 'difficult'), ('behalf', 'jersei'), ('behind', 'comprehens'), ('believ', 'continu'), ('benefit', 'believ'), ('best', 'control'), ('better', 'understand'), ('beyond', 'liabil'), ('big', 'run'), ('bill', 'thei'), ('billion', 'minut'), ('bipartisan', 'offic'), ('bit', 'tough'), ('black', 'res.'), ('block', 'commerc'), ('board', 'Label'), ('bodi', "n't"), ('border', 'ensur'), ('bottom', 'peacekeep'), ('brac', 'ms.'), ('break', 'particip'), ('bring', 'happen'), ('brought', 'upon'), ('budget', 'work'), ('bui', 'period'), ('build', 'given'), ('burden', 'polic'), ('bush', 'clear'), ('busi', 'know'), ('california', 'addit'), ('call', 'record'), ('came', 'document'), ('campaign', 'paid'), ('capac', 'essenti'), ('capit', 'suppli'), ('card', 'intend'), ('care', 'onli'), ('carolina', 'injuri'), ('carri', 'sector'), ('case', 'worker'), ('caucu', 'owner'), ('caus', 'justic'), ('cbc', 'mission'), ('center', 'regul'), ('certain', 'occup'), ('certainli', 'goe'), ('chair', 'societi'), ('chairman', 'ha'), ('challeng', 'involv'), ('chanc', 'probabl'), ('chang', 'california'), ('charg', 'miss'), ('check', '500'), ('child', 'establish'), ('children', 'ask'), ('china', 'spent'), ('choic', 'underli'), ('citat', 'exactli'), ('citi', 'five'), ('citizen', 'within'), ('civil', 'plai'), ('claim', 'offer'), ('class', 'madam'), ('clean', 'gt'), ('clear', 'center'), ('clearli', 'permit'), ('close', 'industri'), ('colleagu', "''"), ('colleg', 'onc'), ('come', 'mai'), ('commend', 'fix'), ('comment', 'sale'), ('commerc', 'too ...
